# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from scipy.stats import norm, binom, bernoulli
from scipy.stats import pearsonr

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import zscore

from IPython.display import Image, display

# %%
from causallearn.search.ConstraintBased.FCI import fci
from causallearn.search.ConstraintBased.PC import pc
from causallearn.utils.GraphUtils import GraphUtils

# %%
df = pd.read_csv('data/model_pc_example.csv').values
data = zscore(df)
data
# Out:
# array([[ 1.85340228,  1.95193319,  1.86926175,  1.89623335,  1.88334117],
#        [-1.23420538, -1.19896917, -1.24077098, -1.26268501, -1.25056115],
#        [ 0.2293376 ,  0.12214697,  0.0148352 ,  0.00858759,  0.01147116],
#        ...,
#        [-0.57313623, -0.48831401, -0.47813882, -0.49048656, -0.48421767],
#        [-0.07101832, -0.06209892, -0.07016214, -0.13410844, -0.10299151],
#        [-0.05356988,  0.09362014,  0.13123804,  0.07113242,  0.10125628]])

# %%
cg = pc(data,
        independence_test_method='fisherz',
        node_names=['a','b','c','d','e'],
        verbose=False)
# Out:
# Depth=2, working on node 4: 100%|████████████████| 5/5 [00:00<00:00, 997.36it/s]

# %%
pyd = GraphUtils.to_pydot(cg.G)
pyd

# %%
Image(pyd.create_png(), width=150, height=150)

# %%
g, edges = fci(data, independence_test_method='fisherz',
               node_names=['a','b','c','d','e'],
               verbose=False)
# Out:
# Depth=0, working on node 4: 100%|███████████████| 5/5 [00:00<00:00, 1917.48it/s]

# %%
pdy = GraphUtils.to_pydot(g)
Image(pdy.create_png(), width=150, height=150)
